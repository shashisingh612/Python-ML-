# %%
#Insights
##weekends has less number of views/Traffic.
#overall total no of views are increasing from August to October 
# In the middle of september traffic started decreasing but again increased in october 
#conversion is less in october compare to Auguste & September
#for converted ones, Min Employee Size : 23 & Max Employee Size:466
#for converted ones , they are going for 
#postgrey ---> redshift

# %%
import pandas as pd

# %%
#df = pd.read_excel("C:\\Users\\ac36345\\Downloads\\Pattern_Analysis_Round_-_Data_Sheet.xlsx",engine='xlrd')

# %%
df1 = pd.read_csv("C:\\Users\\ac36345\\Downloads\\test_data1.csv", encoding='cp1252')

# %%
df2 = pd.read_csv("C:\\Users\\ac36345\\Downloads\\test_data2.csv",encoding='cp1252')

# %%
df1.describe()
# Out:
#                         Email       Current Status            Type  \
# count                      71                   71              71
# unique                     71                   11               5
# top     41@customer-leads.com  No Response - Email  create-account
# freq                        1                   28              39
#
#                                                      Date Started Free Trial?  \
# count                                                  71                  71
# unique                                                 71                   2
# top     Thu Aug 30 2018 09:11:34 GMT+0800 (Philippine ...                  No
# freq                                                    1                  55
#
#        Decision Maker                                demo_date  \
# count              71                                       37
# unique              3                                       36
# ...

# %%
df2.describe()
#weekends has less number of views, mean value is less
#overall total no of views are increasing from August to October 
# in mid september traffic started decreasing but again increased in october
# Out:
#        8/1/2018 0:00  8/2/2018 0:00  8/3/2018 0:00  8/4/2018 0:00  \
# count      39.000000      39.000000      39.000000      39.000000
# mean        3.538462       2.589744       3.025641       0.820513
# std         7.809731       5.265168       6.213259       1.861971
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         1.500000       2.000000       4.000000       0.000000
# max        32.000000      17.000000      25.000000       8.000000
#
#        8/5/2018 0:00  8/6/2018 0:00  8/7/2018 0:00  8/8/2018 0:00  \
# count      39.000000      39.000000      39.000000      39.000000
# mean        0.974359       3.461538       3.871795       3.025641
# std         1.979994       7.010692       7.867921       6.535277
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
#top views/Traffic
df2.sort_values(by=['Total Views'],ascending=False).head(10)
# Out:
#                                             Blog Url  8/1/2018 0:00  \
# 0  https://abc.com/blog/redshift-vacuum-and-analyze/             32
# 1  https://abc.com/blog/amazon-redshift-pros-and-...             25
# 2   https://abc.com/blog/redshift-distribution-keys/             13
# 3   https://abc.com/blog/postgresql-to-redshift-etl/             25
# 4  https://abc.com/blog/redshift-sort-keys-choosi...              8
# 5        https://abc.com/blog/mysql-to-redshift-etl/              5
# 6        https://abc.com/blog/redshift-architecture/              5
# 7  https://abc.com/blog/druid-vs-redshift-data-wa...             12
# 8         https://abc.com/blog/redshift-vs-bigquery/             10
# 9      https://abc.com/blog/mongodb-to-redshift-etl/              1
#
#    8/2/2018 0:00  8/3/2018 0:00  8/4/2018 0:00  8/5/2018 0:00  8/6/2018 0:00  \
# 0             15             25              5              4             25
# ...

# %%
set(df1.loc[df1['Type']=='request-quote']['Referrer URL'])
# Out:
# {'https://abc.com/blog/looker-vs-periscope-vs-c...',
#  'https://abc.com/blog/postgresql-to-redshift-etl/',
#  'https://abc.com/blog/schema-mapper-hevo/',
#  'https://stitch.abc.io/comparison'}

# %%
set(df1.loc[df1['Type']=='request-demo']['Referrer URL'])
# Out:
# {'https://abc.com/',
#  'https://abc.com/blog/amazon-redshift-pros-and-cons/',
#  'https://abc.com/blog/mongodb-to-redshift-etl/',
#  'https://abc.com/blog/postgresql-to-redshift-etl/',
#  'https://abc.com/integrations',
#  nan}

# %%
set(df1.loc[df1['Type']=='free-trial']['Referrer URL'])
# Out:
# {'https://abc.com/?ref=producthunt',
#  'https://abc.com/blog/kafka-exactly-once/',
#  'https://abc.com/blog/looker-vs-periscope-vs-c...',
#  'https://abc.com/blog/looker-vs-periscope-vs-chartio/',
#  'https://abc.com/blog/mysql-to-redshift-etl/',
#  'https://abc.com/blog/postgresql-to-redshift-etl/',
#  'https://abc.com/blog/redshift-vs-bigquery/',
#  'https://abc.com/integrations',
#  'https://stitch.abc.io/comparison',
#  'https://try.abc.com/mysql-etl-free-trial'}

# %%
#######Blogs reponsible for conversion
#https://abc.com/blog/postgresql-to-redshift-etl/
#https://abc.com/blog/mongodb-to-redshift-etl/
#https://hevo.io/

# %%
df1.loc[df1['Current Status']=='Converted']
#conversion is less in october compare to Auguste & September
#for converted ones, Min Employee Size : 23 & Max Employee Size:466
#for converted ones , they are going for 
#postgrey ---> redshift
# mongo  ----> redshift
# Out:
#                     Email Current Status            Type  \
# 40  41@customer-leads.com      Converted   request-quote
# 53  54@customer-leads.com      Converted      free-trial
# 55  56@customer-leads.com      Converted  create-account
# 61  62@customer-leads.com      Converted    request-demo
# 65  66@customer-leads.com      Converted  create-account
# 68  69@customer-leads.com      Converted      contact-us
#
#                                                  Date Started Free Trial?  \
# 40            Tue Aug 07 2018 20:59:08 GMT-0700 (PDT)                 Yes
# 53  Tue Aug 28 2018 11:39:36 GMT-0400 (Eastern Day...                 Yes
# 55  Thu Aug 30 2018 09:11:34 GMT+0800 (Philippine ...                 Yes
# 61  Thu Sep 13 2018 15:06:54 GMT+0530 (India Stand...                 Yes
# 65             Monday, September 24, 2018, 9:21:11 PM                 Yes
# 68            Tuesday, September 25, 2018, 6:57:23 PM                 Yes
#
# ...
