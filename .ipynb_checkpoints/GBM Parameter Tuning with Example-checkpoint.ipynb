# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingClassifier  #GBM algorithm
#from sklearn.grid_search import GridSearchCV   #Perforing grid search
from sklearn.model_selection import GridSearchCV, StratifiedKFold,cross_validate
from sklearn import metrics

import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12, 4

train = pd.read_csv("C:\\Users\\ac36345\\Desktop\\nlp code\\train_modified.csv")
target = 'Disbursed'
IDcol = 'ID'

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87020 entries, 0 to 87019
# Data columns (total 51 columns):
# Disbursed                        87020 non-null float64
# Existing_EMI                     87020 non-null float64
# ID                               87020 non-null object
# Loan_Amount_Applied              87020 non-null float64
# Loan_Tenure_Applied              87020 non-null float64
# Monthly_Income                   87020 non-null int64
# Var4                             87020 non-null int64
# Var5                             87020 non-null int64
# Age                              87020 non-null int64
# EMI_Loan_Submitted_Missing       87020 non-null int64
# Interest_Rate_Missing            87020 non-null int64
# Loan_Amount_Submitted_Missing    87020 non-null int64
# Loan_Tenure_Submitted_Missing    87020 non-null int64
# Processing_Fee_Missing           87020 non-null int64
# Device_Type_0                    87020 non-null float64
# Device_Type_1                    87020 non-null float64
# Filled_Form_0                    87020 non-null float64
# Filled_Form_1                    87020 non-null float64
# Gender_0                         87020 non-null float64
# Gender_1                         87020 non-null float64
# Var1_0                           87020 non-null float64
# Var1_1                           87020 non-null float64
# Var1_2                           87020 non-null float64
# Var1_3                           87020 non-null float64
# Var1_4                           87020 non-null float64
# Var1_5                           87020 non-null float64
# Var1_6                           87020 non-null float64
# Var1_7                           87020 non-null float64
# Var1_8                           87020 non-null float64
# Var1_9                           87020 non-null float64
# Var1_10                          87020 non-null float64
# Var1_11                          87020 non-null float64
# Var1_12                          87020 non-null float64
# Var1_13                          87020 non-null float64
# Var1_14                          87020 non-null float64
# Var1_15                          87020 non-null float64
# Var1_16                          87020 non-null float64
# Var1_17                          87020 non-null float64
# Var1_18                          87020 non-null float64
# Var2_0                           87020 non-null float64
# Var2_1                           87020 non-null float64
# Var2_2                           87020 non-null float64
# Var2_3                           87020 non-null float64
# Var2_4                           87020 non-null float64
# Var2_5                           87020 non-null float64
# Var2_6                           87020 non-null float64
# Mobile_Verified_0                87020 non-null float64
# Mobile_Verified_1                87020 non-null float64
# Source_0                         87020 non-null float64
# Source_1                         87020 non-null float64
# Source_2                         87020 non-null float64
# dtypes: float64(41), int64(9), object(1)
# memory usage: 33.9+ MB

# %%
train.columns
# Out:
# Index(['Disbursed', 'Existing_EMI', 'ID', 'Loan_Amount_Applied',
#        'Loan_Tenure_Applied', 'Monthly_Income', 'Var4', 'Var5', 'Age',
#        'EMI_Loan_Submitted_Missing', 'Interest_Rate_Missing',
#        'Loan_Amount_Submitted_Missing', 'Loan_Tenure_Submitted_Missing',
#        'Processing_Fee_Missing', 'Device_Type_0', 'Device_Type_1',
#        'Filled_Form_0', 'Filled_Form_1', 'Gender_0', 'Gender_1', 'Var1_0',
#        'Var1_1', 'Var1_2', 'Var1_3', 'Var1_4', 'Var1_5', 'Var1_6', 'Var1_7',
#        'Var1_8', 'Var1_9', 'Var1_10', 'Var1_11', 'Var1_12', 'Var1_13',
#        'Var1_14', 'Var1_15', 'Var1_16', 'Var1_17', 'Var1_18', 'Var2_0',
#        'Var2_1', 'Var2_2', 'Var2_3', 'Var2_4', 'Var2_5', 'Var2_6',
#        'Mobile_Verified_0', 'Mobile_Verified_1', 'Source_0', 'Source_1',
#        'Source_2'],
#       dtype='object')

# %%
def modelfit(alg, dtrain, predictors, performCV=True, printFeatureImportance=True, cv_folds=5):
#Fit the algorithm on the data
alg.fit(dtrain[predictors], dtrain['Disbursed'])

#Predict training set:
dtrain_predictions = alg.predict(dtrain[predictors])
dtrain_predprob = alg.predict_proba(dtrain[predictors])[:,1]

#Perform cross-validation:
if performCV:
cv_score = cross_validate(alg, dtrain[predictors], dtrain['Disbursed'], cv=cv_folds, scoring='roc_auc')

#Print model report:
print("\nModel Report")
print("Accuracy : %.4g" % metrics.accuracy_score(dtrain['Disbursed'].values, dtrain_predictions))
print("AUC Score (Train): %f" % metrics.roc_auc_score(dtrain['Disbursed'], dtrain_predprob))

if performCV:
#print("CV Score : Mean - %.7g | Std - %.7g | Min - %.7g | Max - %.7g" % (np.mean(cv_score),np.std(cv_score),np.min(cv_score),np.max(cv_score)))
#print("CV Score,Mean,Std,Min,Max",np.mean(cv_score),np.std(cv_score),np.min(cv_score),np.max(cv_score))
print('cv_score:',cv_score)

#Print Feature Importance:
if printFeatureImportance:
feat_imp = pd.Series(alg.feature_importances_, predictors).sort_values(ascending=False)
feat_imp.plot(kind='bar', title='Feature Importances')
plt.ylabel('Feature Importance Score')

# %%
#Choose all predictors except target & IDcols
predictors = [x for x in train.columns if x not in [target, IDcol]]
gbm0 = GradientBoostingClassifier(random_state=10)
modelfit(gbm0, train, predictors)
# Out:
# Model Report
# Accuracy : 0.9856
# AUC Score (Train): 0.862264
# cv_score: {'fit_time': array([7.60319519, 7.4010148 , 7.44478893, 7.82223487, 7.71642971]), 'score_time': array([0.10592198, 0.0380466 , 0.030303  , 0.03085303, 0.0297842 ]), 'test_score': array([0.82370274, 0.82080501, 0.83898472, 0.84385582, 0.83194596]), 'train_score': array([0.86527752, 0.86521175, 0.86067949, 0.86186765, 0.86762561])}

# %%
#Choose all predictors except target & IDcols
predictors = [x for x in train.columns if x not in [target, IDcol]]
param_test1 = {'n_estimators':range(20,81,10)}
gsearch1 = GridSearchCV(estimator = GradientBoostingClassifier(learning_rate=0.1, min_samples_split=500,min_samples_leaf=50,max_depth=8,max_features='sqrt',subsample=0.8,random_state=10), 
param_grid = param_test1, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch1.fit(train[predictors],train[target])
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=8,
#               max_features='sqrt', max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=50, min_sa...      subsample=0.8, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False),
#        fit_params=None, iid=False, n_jobs=4,
#        param_grid={'n_estimators': range(20, 81, 10)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='roc_auc', verbose=0)

# %%
gsearch1.cv_results_, gsearch1.best_params_, gsearch1.best_score_
# Out:
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# ({'mean_fit_time': array([ 2.6553494 ,  4.63895659,  5.45858202,  5.95985312,  7.39178009,
#          10.13560362,  9.29051652]),
#   'std_fit_time': array([0.46937976, 0.2187149 , 0.29418474, 0.22356513, 0.26150233,
#          1.44663235, 1.7990156 ]),
#   'mean_score_time': array([0.03800278, 0.05360575, 0.05478964, 0.06746473, 0.07082596,
#          0.10957603, 0.07157869]),
#   'std_score_time': array([0.01035362, 0.0123245 , 0.00302344, 0.0057477 , 0.00691117,
#          0.01970462, 0.01615937]),
#   'param_n_estimators': masked_array(data=[20, 30, 40, 50, 60, 70, 80],
#                mask=[False, False, False, False, False, False, False],
#          fill_value='?',
#               dtype=object),
#   'params': [{'n_estimators': 20},
#    {'n_estimators': 30},
#    {'n_estimators': 40},
#    {'n_estimators': 50},
#    {'n_estimators': 60},
#    {'n_estimators': 70},
#    {'n_estimators': 80}],
#   'split0_test_score': array([0.81912514, 0.82194546, 0.82289556, 0.82256628, 0.8238819 ,
#          0.82398845, 0.82199977]),
#   'split1_test_score': array([0.82940605, 0.83392729, 0.83304453, 0.83464917, 0.83626056,
#          0.83599108, 0.83597782]),
#   'split2_test_score': array([0.83761015, 0.84342264, 0.84908478, 0.84956946, 0.85022382,
#          0.84933838, 0.84987852]),
#   'split3_test_score': array([0.84920645, 0.85143299, 0.85106211, 0.85186448, 0.8528124 ,
#          0.8520571 , 0.8505963 ]),
#   'split4_test_score': array([0.83152469, 0.83412315, 0.83553482, 0.83472223, 0.83376146,
#          0.83319819, 0.83189305]),
#   'mean_test_score': array([0.83337449, 0.83697031, 0.83832436, 0.83867433, 0.83938803,
#          0.83891464, 0.83806909]),
#   'std_test_score': array([0.00990763, 0.00993895, 0.01050469, 0.01080717, 0.01076576,
#          0.01044409, 0.01092825]),
#   'rank_test_score': array([7, 6, 4, 3, 1, 2, 5]),
#   'split0_train_score': array([0.88541956, 0.89214138, 0.89663367, 0.90215111, 0.90722814,
#          0.91111406, 0.91496001]),
#   'split1_train_score': array([0.8816282 , 0.88980173, 0.89515634, 0.90009053, 0.90603252,
#          0.91131578, 0.91487142]),
#   'split2_train_score': array([0.87952447, 0.88769522, 0.89383802, 0.89988199, 0.90449751,
#          0.90799863, 0.91182728]),
#   'split3_train_score': array([0.88130481, 0.88807016, 0.89373643, 0.90062488, 0.90533411,
#          0.91018913, 0.9151984 ]),
#   'split4_train_score': array([0.88308312, 0.89024709, 0.89734987, 0.90429541, 0.9093609 ,
#          0.91362315, 0.91696191]),
#   'mean_train_score': array([0.88219203, 0.88959112, 0.89534287, 0.90140879, 0.90649064,
#          0.91084815, 0.9147638 ]),
#   'std_train_score': array([0.00197139, 0.00160538, 0.00145425, 0.00164724, 0.00169129,
#          0.00181902, 0.00165492])},
#  {'n_estimators': 60},
#  0.8393880266861308)

# %%
param_test2 = {'max_depth':range(5,16,2), 'min_samples_split':range(200,1001,200)}
gsearch2 = GridSearchCV(estimator = GradientBoostingClassifier(learning_rate=0.1, n_estimators=60, max_features='sqrt', subsample=0.8, random_state=10), 
param_grid = param_test2, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch2.fit(train[predictors],train[target])
gsearch2.cv_results_, gsearch2.best_params_, gsearch2.best_score_
# Out:
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# ({'mean_fit_time': array([ 4.66445007,  5.02592754,  4.35020819,  4.413482  ,  4.2551177 ,
#           6.47707925,  6.11401873,  6.04734674,  5.87292829,  5.42859941,
#           8.97182951,  8.11494617,  7.70808001,  8.38916707,  7.55943031,
#          11.45023355, 10.18432388,  9.65692167,  8.98267531,  8.34502764,
#          14.52256689, 12.08750539, 10.845332  , 10.19119954,  9.50202079,
#          17.45371337, 14.29765463, 13.66467729, 13.23552346, 10.21416092]),
#   'std_fit_time': array([0.49548061, 0.46525004, 0.15891009, 0.05775736, 0.0934233 ,
#          0.35037924, 0.07586905, 0.18290035, 0.09338645, 0.1510351 ,
#          0.31150673, 0.26810878, 0.1713543 , 0.76639695, 0.41572533,
#          0.44566108, 0.34096517, 0.12444743, 0.2347723 , 0.09257183,
#          0.11909559, 0.39500256, 0.33811935, 0.47631766, 0.25146056,
#          0.69612972, 0.16572768, 0.79739938, 0.3654806 , 1.50394195]),
#   'mean_score_time': array([0.06842165, 0.06419644, 0.06245866, 0.05942521, 0.06012149,
#          0.06887627, 0.07306385, 0.07615242, 0.07552452, 0.08248897,
#          0.0821291 , 0.07870173, 0.08646526, 0.07736468, 0.07584181,
#          0.09573336, 0.09821434, 0.0910995 , 0.08857946, 0.08878474,
#          0.10355062, 0.10135875, 0.0945159 , 0.092974  , 0.09283643,
#          0.11444755, 0.10056534, 0.10557923, 0.09831424, 0.08519154]),
#   'std_score_time': array([0.00898525, 0.00841713, 0.00767888, 0.00487193, 0.01159797,
#          0.00703344, 0.01096712, 0.00930441, 0.01311523, 0.02282632,
#          0.00716011, 0.00409717, 0.00578601, 0.00570162, 0.00452336,
#          0.0064652 , 0.01253282, 0.00946112, 0.00773439, 0.00857408,
#          0.01005588, 0.01220577, 0.0071802 , 0.00490184, 0.00973303,
#          0.01292011, 0.00873522, 0.01403624, 0.00625783, 0.01465959]),
#   'param_max_depth': masked_array(data=[5, 5, 5, 5, 5, 7, 7, 7, 7, 7, 9, 9, 9, 9, 9, 11, 11,
#                      11, 11, 11, 13, 13, 13, 13, 13, 15, 15, 15, 15, 15],
#                mask=[False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False],
#          fill_value='?',
#               dtype=object),
#   'param_min_samples_split': masked_array(data=[200, 400, 600, 800, 1000, 200, 400, 600, 800, 1000,
#                      200, 400, 600, 800, 1000, 200, 400, 600, 800, 1000,
#                      200, 400, 600, 800, 1000, 200, 400, 600, 800, 1000],
#                mask=[False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False],
#          fill_value='?',
#               dtype=object),
#   'params': [{'max_depth': 5, 'min_samples_split': 200},
#    {'max_depth': 5, 'min_samples_split': 400},
#    {'max_depth': 5, 'min_samples_split': 600},
#    {'max_depth': 5, 'min_samples_split': 800},
#    {'max_depth': 5, 'min_samples_split': 1000},
#    {'max_depth': 7, 'min_samples_split': 200},
#    {'max_depth': 7, 'min_samples_split': 400},
#    {'max_depth': 7, 'min_samples_split': 600},
#    {'max_depth': 7, 'min_samples_split': 800},
#    {'max_depth': 7, 'min_samples_split': 1000},
#    {'max_depth': 9, 'min_samples_split': 200},
#    {'max_depth': 9, 'min_samples_split': 400},
#    {'max_depth': 9, 'min_samples_split': 600},
#    {'max_depth': 9, 'min_samples_split': 800},
#    {'max_depth': 9, 'min_samples_split': 1000},
#    {'max_depth': 11, 'min_samples_split': 200},
#    {'max_depth': 11, 'min_samples_split': 400},
#    {'max_depth': 11, 'min_samples_split': 600},
#    {'max_depth': 11, 'min_samples_split': 800},
#    {'max_depth': 11, 'min_samples_split': 1000},
#    {'max_depth': 13, 'min_samples_split': 200},
#    {'max_depth': 13, 'min_samples_split': 400},
#    {'max_depth': 13, 'min_samples_split': 600},
#    {'max_depth': 13, 'min_samples_split': 800},
#    {'max_depth': 13, 'min_samples_split': 1000},
#    {'max_depth': 15, 'min_samples_split': 200},
#    {'max_depth': 15, 'min_samples_split': 400},
#    {'max_depth': 15, 'min_samples_split': 600},
#    {'max_depth': 15, 'min_samples_split': 800},
#    {'max_depth': 15, 'min_samples_split': 1000}],
#   'split0_test_score': array([0.8197056 , 0.82040931, 0.82017904, 0.81933722, 0.81409821,
#          0.82463717, 0.82426273, 0.82174253, 0.82074064, 0.82298977,
#          0.82804104, 0.82399188, 0.82555879, 0.82315532, 0.82557503,
#          0.81618362, 0.8213307 , 0.81993998, 0.82076328, 0.82091557,
#          0.81035054, 0.81801098, 0.82082936, 0.81732247, 0.82148036,
#          0.80443252, 0.80716344, 0.81618213, 0.81101915, 0.81169542]),
#   'split1_test_score': array([0.81919019, 0.82081313, 0.8159944 , 0.82361619, 0.82639399,
#          0.82731996, 0.82835809, 0.82845024, 0.83569382, 0.82964008,
#          0.83097022, 0.83080729, 0.82727137, 0.83603087, 0.83366284,
#          0.82516058, 0.82499308, 0.82887006, 0.83205156, 0.8346167 ,
#          0.82327022, 0.82715212, 0.83226125, 0.83329   , 0.83135403,
#          0.81488573, 0.8253873 , 0.82689407, 0.83222878, 0.83207454]),
#   'split2_test_score': array([0.84142195, 0.84309975, 0.84532603, 0.84280533, 0.84314503,
#          0.84220311, 0.84740653, 0.84319728, 0.85101881, 0.84511085,
#          0.8454191 , 0.84824005, 0.84682477, 0.84944643, 0.85007483,
#          0.83945259, 0.83757208, 0.84587405, 0.83618538, 0.84290138,
#          0.84138628, 0.83856007, 0.84379984, 0.84866756, 0.84440515,
#          0.8233866 , 0.83719819, 0.84231814, 0.83894173, 0.85304785]),
#   'split3_test_score': array([0.85066322, 0.84512963, 0.85290561, 0.85076573, 0.85027765,
#          0.84383263, 0.84878758, 0.84111445, 0.84721682, 0.85270117,
#          0.8500056 , 0.84810907, 0.84047634, 0.84759803, 0.84895529,
#          0.839113  , 0.83568565, 0.84403845, 0.84369994, 0.85018869,
#          0.83178928, 0.84124381, 0.84356621, 0.84730681, 0.84197938,
#          0.83234118, 0.8246809 , 0.83542026, 0.83857751, 0.84146444]),
#   'split4_test_score': array([0.83384605, 0.8330842 , 0.8349137 , 0.83240225, 0.83305218,
#          0.83025594, 0.83433436, 0.8394856 , 0.83460584, 0.83801505,
#          0.82460411, 0.83529594, 0.82572616, 0.83532407, 0.82939881,
#          0.82866773, 0.82797406, 0.82654988, 0.82474403, 0.82968624,
#          0.81604641, 0.82551966, 0.8209217 , 0.82741332, 0.82938802,
#          0.82004575, 0.82115518, 0.82303185, 0.82422427, 0.82693764]),
#   'mean_test_score': array([0.8329654 , 0.8325072 , 0.83386376, 0.83378534, 0.83339341,
#          0.83364976, 0.83662986, 0.83479802, 0.83785519, 0.83769138,
#          0.94113633, 0.93226899, 0.92146584, 0.91922341, 0.91349728,
#          0.96684674, 0.95088631, 0.9381217 , 0.93750792, 0.92904755,
#          0.98242242, 0.96642368, 0.95764696, 0.94872721, 0.9419266 ,
#          0.98982104, 0.97709819, 0.96688907, 0.95766871, 0.94973188]),
#   'mean_train_score': array([0.87417277, 0.87244764, 0.86901881, 0.86826378, 0.86701314,
#          0.90534656, 0.89837747, 0.89570055, 0.89254933, 0.88885099,
#          0.93720162, 0.92685231, 0.91970195, 0.91449364, 0.90954133,
#          0.96281158, 0.94744014, 0.93870004, 0.93106794, 0.92567955,
#          0.98067284, 0.96454897, 0.95330111, 0.94419139, 0.93892425,
#          0.9883645 , 0.97533127, 0.96332368, 0.95483031, 0.94727051]),
#   'std_train_score': array([0.00075345, 0.00171697, 0.00055434, 0.00167833, 0.00149012,
#          0.0023937 , 0.00105515, 0.00179364, 0.00189632, 0.00179657,
#          0.00246863, 0.00284388, 0.00230203, 0.0025584 , 0.00247215,
#          0.00309438, 0.00203249, 0.00152728, 0.00357384, 0.00205003,
#          0.00125444, 0.00245985, 0.00261221, 0.00277684, 0.00253802,
#          0.00116436, 0.00200026, 0.00240074, 0.0021519 , 0.00277385])},
#  {'max_depth': 9, 'min_samples_split': 800},
#  0.8383109442669946)

# %%
param_test3 = {'min_samples_split':range(1000,2100,200), 'min_samples_leaf':range(30,71,10)}
gsearch3 = GridSearchCV(estimator = GradientBoostingClassifier(learning_rate=0.1, n_estimators=60,max_depth=9,max_features='sqrt', subsample=0.8, random_state=10), 
param_grid = param_test3, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch3.fit(train[predictors],train[target])
gsearch3.cv_results_, gsearch3.best_params_, gsearch3.best_score_
# Out:
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# ({'mean_fit_time': array([7.41590567, 7.11362252, 7.02993593, 7.50406332, 6.60748744,
#          6.33736143, 6.75667968, 6.71040554, 6.57184916, 6.43698549,
#          6.43590331, 6.16645007, 6.92923298, 6.79901361, 6.6542582 ,
#          6.91990843, 7.45388656, 7.38531609, 8.07244763, 6.97168021,
#          6.47493563, 6.35410748, 6.29285378, 6.32556748, 6.92264094,
#          6.79520388, 6.55503302, 6.44788694, 6.37390194, 5.47312856]),
#   'std_fit_time': array([0.16676123, 0.39319179, 0.07516774, 0.44875418, 0.15204754,
#          0.13662406, 0.13854896, 0.22629326, 0.26918751, 0.242133  ,
#          0.15113372, 0.20073099, 0.26095047, 0.19453789, 0.27845855,
#          0.20947685, 0.2187643 , 0.10518895, 0.14178421, 0.24347034,
#          0.17093207, 0.12751891, 0.18774639, 0.12692121, 0.07030759,
#          0.13633028, 0.14774257, 0.09320742, 0.10475801, 0.71874341]),
#   'mean_score_time': array([0.07736206, 0.09747739, 0.07389107, 0.08066459, 0.07914886,
#          0.07190723, 0.08712773, 0.07324276, 0.07581382, 0.07965441,
#          0.08552723, 0.07604928, 0.07928338, 0.07653475, 0.0732655 ,
#          0.08832035, 0.09111962, 0.08277936, 0.08671708, 0.0764957 ,
#          0.07067018, 0.06978707, 0.07260356, 0.0723177 , 0.0746839 ,
#          0.07586846, 0.07447996, 0.07608876, 0.08318806, 0.06322775]),
#   'std_score_time': array([0.01240039, 0.02248178, 0.00604703, 0.0058944 , 0.01266608,
#          0.00413859, 0.00996868, 0.00756352, 0.00473211, 0.01276288,
#          0.00908407, 0.0133124 , 0.00627124, 0.00780037, 0.00993537,
#          0.01715461, 0.02450474, 0.01666572, 0.01922167, 0.00858244,
#          0.00242046, 0.00358594, 0.00578401, 0.00598995, 0.00377992,
#          0.00878453, 0.00674591, 0.00408617, 0.01048545, 0.01391977]),
#   'param_min_samples_leaf': masked_array(data=[30, 30, 30, 30, 30, 30, 40, 40, 40, 40, 40, 40, 50, 50,
#                      50, 50, 50, 50, 60, 60, 60, 60, 60, 60, 70, 70, 70, 70,
#                      70, 70],
#                mask=[False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False],
#          fill_value='?',
#               dtype=object),
#   'param_min_samples_split': masked_array(data=[1000, 1200, 1400, 1600, 1800, 2000, 1000, 1200, 1400,
#                      1600, 1800, 2000, 1000, 1200, 1400, 1600, 1800, 2000,
#                      1000, 1200, 1400, 1600, 1800, 2000, 1000, 1200, 1400,
#                      1600, 1800, 2000],
#                mask=[False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False],
#          fill_value='?',
#               dtype=object),
#   'params': [{'min_samples_leaf': 30, 'min_samples_split': 1000},
#    {'min_samples_leaf': 30, 'min_samples_split': 1200},
#    {'min_samples_leaf': 30, 'min_samples_split': 1400},
#    {'min_samples_leaf': 30, 'min_samples_split': 1600},
#    {'min_samples_leaf': 30, 'min_samples_split': 1800},
#    {'min_samples_leaf': 30, 'min_samples_split': 2000},
#    {'min_samples_leaf': 40, 'min_samples_split': 1000},
#    {'min_samples_leaf': 40, 'min_samples_split': 1200},
#    {'min_samples_leaf': 40, 'min_samples_split': 1400},
#    {'min_samples_leaf': 40, 'min_samples_split': 1600},
#    {'min_samples_leaf': 40, 'min_samples_split': 1800},
#    {'min_samples_leaf': 40, 'min_samples_split': 2000},
#    {'min_samples_leaf': 50, 'min_samples_split': 1000},
#    {'min_samples_leaf': 50, 'min_samples_split': 1200},
#    {'min_samples_leaf': 50, 'min_samples_split': 1400},
#    {'min_samples_leaf': 50, 'min_samples_split': 1600},
#    {'min_samples_leaf': 50, 'min_samples_split': 1800},
#    {'min_samples_leaf': 50, 'min_samples_split': 2000},
#    {'min_samples_leaf': 60, 'min_samples_split': 1000},
#    {'min_samples_leaf': 60, 'min_samples_split': 1200},
#    {'min_samples_leaf': 60, 'min_samples_split': 1400},
#    {'min_samples_leaf': 60, 'min_samples_split': 1600},
#    {'min_samples_leaf': 60, 'min_samples_split': 1800},
#    {'min_samples_leaf': 60, 'min_samples_split': 2000},
#    {'min_samples_leaf': 70, 'min_samples_split': 1000},
#    {'min_samples_leaf': 70, 'min_samples_split': 1200},
#    {'min_samples_leaf': 70, 'min_samples_split': 1400},
#    {'min_samples_leaf': 70, 'min_samples_split': 1600},
#    {'min_samples_leaf': 70, 'min_samples_split': 1800},
#    {'min_samples_leaf': 70, 'min_samples_split': 2000}],
#   'split0_test_score': array([0.82324736, 0.81858115, 0.82069308, 0.81426925, 0.82001475,
#          0.82074681, 0.82673915, 0.81771726, 0.82669113, 0.81807009,
#          0.81625725, 0.81867067, 0.82375705, 0.82254925, 0.82040919,
#   'std_train_score': array([0.00120381, 0.00136402, 0.00199363, 0.00188713, 0.00299815,
#          0.00203132, 0.00242617, 0.00150877, 0.00198222, 0.00235486,
#          0.0012834 , 0.00300401, 0.00042048, 0.00187676, 0.00192923,
#          0.00101685, 0.00308224, 0.00146111, 0.00199724, 0.00160842,
#          0.00229949, 0.00187811, 0.00252494, 0.00217054, 0.00133851,
#          0.00186496, 0.00208764, 0.00197512, 0.00253973, 0.00165196])},
#  {'min_samples_leaf': 60, 'min_samples_split': 1200},
#  0.839759762884295)

# %%
modelfit(gsearch3.best_estimator_, train, predictors)
# Out:
# Model Report
# Accuracy : 0.9854
# AUC Score (Train): 0.896453
# cv_score: {'fit_time': array([3.92144465, 3.89796615, 3.99039054, 4.00024176, 4.10257673]), 'score_time': array([0.04871106, 0.05024481, 0.05331969, 0.0494554 , 0.04924798]), 'test_score': array([0.82554736, 0.83690047, 0.84907209, 0.85276718, 0.83451171]), 'train_score': array([0.90114288, 0.89872655, 0.89959656, 0.89905175, 0.90307445])}

# %%
param_test4 = {'max_features':range(7,20,2)}
gsearch4 = GridSearchCV(estimator = GradientBoostingClassifier(learning_rate=0.1, n_estimators=60,max_depth=9, min_samples_split=1200, min_samples_leaf=60, subsample=0.8, random_state=10),
param_grid = param_test4, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch4.fit(train[predictors],train[target])
gsearch4.cv_results_, gsearch4.best_params_, gsearch4.best_score_
# Out:
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# ({'mean_fit_time': array([ 6.70788412,  7.6158175 ,  8.91973448,  9.90143361, 10.82832112,
#          11.85687556, 11.72505589]),
#   'std_fit_time': array([0.10823652, 0.2032599 , 0.09031768, 0.11876251, 0.24488491,
#          0.15413684, 1.20332048]),
#   'mean_score_time': array([0.0764349 , 0.0708571 , 0.07188311, 0.0698101 , 0.07973132,
#          0.06750026, 0.06194692]),
#   'std_score_time': array([0.00443063, 0.00840112, 0.0072433 , 0.00884345, 0.01536783,
#          0.00878187, 0.00987641]),
#   'param_max_features': masked_array(data=[7, 9, 11, 13, 15, 17, 19],
#                mask=[False, False, False, False, False, False, False],
#          fill_value='?',
#               dtype=object),
#   'params': [{'max_features': 7},
#    {'max_features': 9},
#    {'max_features': 11},
#    {'max_features': 13},
#    {'max_features': 15},
#    {'max_features': 17},
#    {'max_features': 19}],
#   'split0_test_score': array([0.82554736, 0.8249023 , 0.82653644, 0.82533916, 0.82501949,
#          0.82380861, 0.82412588]),
#   'split1_test_score': array([0.83690047, 0.82978106, 0.83318859, 0.82984577, 0.82925605,
#          0.82833396, 0.82784908]),
#   'split2_test_score': array([0.84907209, 0.84821181, 0.85126487, 0.84833084, 0.85189635,
#          0.84692722, 0.84483369]),
#   'split3_test_score': array([0.85276718, 0.84841257, 0.85193944, 0.85059573, 0.85113833,
#          0.8451077 , 0.84988278]),
#   'split4_test_score': array([0.83451171, 0.83108356, 0.83302934, 0.83278289, 0.83760181,
#          0.82769673, 0.82948892]),
#   'mean_test_score': array([0.83975976, 0.83647826, 0.83919173, 0.83737888, 0.83898241,
#          0.83437485, 0.83523607]),
#   'std_test_score': array([0.00993602, 0.0098799 , 0.0104157 , 0.01017306, 0.01100916,
#          0.00964874, 0.01017521]),
#   'rank_test_score': array([1, 5, 2, 4, 3, 7, 6]),
#   'split0_train_score': array([0.90114288, 0.90199818, 0.90171188, 0.9058068 , 0.90425781,
#          0.9059019 , 0.90773862]),
#   'split1_train_score': array([0.89872655, 0.90030829, 0.90397443, 0.90469945, 0.90711349,
#          0.90614986, 0.90776429]),
#   'split2_train_score': array([0.89959656, 0.89904026, 0.90290968, 0.90279956, 0.90277095,
#          0.9079397 , 0.9037782 ]),
#   'split3_train_score': array([0.89905175, 0.9023013 , 0.90237086, 0.90523397, 0.90526869,
#          0.90552331, 0.90918722]),
#   'split4_train_score': array([0.90307445, 0.9054952 , 0.9062966 , 0.9118555 , 0.90964862,
#          0.90881679, 0.90966861]),
#   'mean_train_score': array([0.90031844, 0.90182864, 0.90345269, 0.90607906, 0.90581191,
#          0.90686631, 0.90762739]),
#   'std_train_score': array([0.00160842, 0.00218094, 0.00160348, 0.00305987, 0.00238211,
#          0.0012809 , 0.00207109])},
#  {'max_features': 7},
#  0.839759762884295)

# %%
param_test5 = {'subsample':[0.6,0.7,0.75,0.8,0.85,0.9]}
gsearch5 = GridSearchCV(estimator = GradientBoostingClassifier(learning_rate=0.1, n_estimators=60,max_depth=9,min_samples_split=1200, min_samples_leaf=60, subsample=0.8, random_state=10,max_features=7),
param_grid = param_test5, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch5.fit(train[predictors],train[target])
gsearch5.cv_results_, gsearch5.best_params_, gsearch5.best_score_
# Out:
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\ac36345\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# ({'mean_fit_time': array([5.96286888, 6.31169071, 6.54328203, 6.80938563, 6.93140321,
#          6.12470126]),
#   'std_fit_time': array([0.12328584, 0.18117939, 0.22317552, 0.15567003, 0.16535715,
#          0.98944874]),
#   'mean_score_time': array([0.07161846, 0.07849207, 0.08148437, 0.08590159, 0.08115096,
#          0.07260361]),
#   'std_score_time': array([0.004796  , 0.00803561, 0.00668327, 0.010616  , 0.01268472,
#          0.01419593]),
#   'param_subsample': masked_array(data=[0.6, 0.7, 0.75, 0.8, 0.85, 0.9],
#                mask=[False, False, False, False, False, False],
#          fill_value='?',
#               dtype=object),
#   'params': [{'subsample': 0.6},
#    {'subsample': 0.7},
#    {'subsample': 0.75},
#    {'subsample': 0.8},
#    {'subsample': 0.85},
#    {'subsample': 0.9}],
#   'split0_test_score': array([0.82291134, 0.81776425, 0.8216195 , 0.82554736, 0.8282569 ,
#          0.82487361]),
#   'split1_test_score': array([0.83378506, 0.83223518, 0.83092677, 0.83690047, 0.83688207,
#          0.83439822]),
#   'split2_test_score': array([0.84589578, 0.85063566, 0.85114607, 0.84907209, 0.85424577,
#          0.84957426]),
#   'split3_test_score': array([0.84823063, 0.8503603 , 0.84543278, 0.85276718, 0.85076596,
#          0.84976822]),
#   'split4_test_score': array([0.83140979, 0.8332604 , 0.83094788, 0.83451171, 0.83413934,
#          0.83280355]),
#   'mean_test_score': array([0.83644652, 0.83685116, 0.8360146 , 0.83975976, 0.84085801,
#          0.83828357]),
#   'std_test_score': array([0.00942133, 0.01241789, 0.01073722, 0.00993602, 0.00997132,
#          0.00984206]),
#   'rank_test_score': array([5, 4, 6, 2, 1, 3]),
#   'split0_train_score': array([0.89320568, 0.89671905, 0.89637448, 0.90114288, 0.90281128,
#          0.90239041]),
#   'split1_train_score': array([0.89224107, 0.89419815, 0.89659253, 0.89872655, 0.90049759,
#          0.90188684]),
#   'split2_train_score': array([0.89288785, 0.89411921, 0.89703204, 0.89959656, 0.90219814,
#          0.90027728]),
#   'split3_train_score': array([0.8906983 , 0.89245654, 0.89860446, 0.89905175, 0.90166094,
#          0.90035859]),
#   'split4_train_score': array([0.8978264 , 0.89912604, 0.90020152, 0.90307445, 0.90089166,
#          0.90273945]),
#   'mean_train_score': array([0.89337186, 0.8953238 , 0.89776101, 0.90031844, 0.90161192,
#          0.90153052]),
#   'std_train_score': array([0.00238878, 0.0023385 , 0.00144822, 0.00160842, 0.00084203,
#          0.00102683])},
#  {'subsample': 0.85},
#  0.840858008321874)

# %%
predictors = [x for x in train.columns if x not in [target, IDcol]]
gbm_tuned_1 = GradientBoostingClassifier(learning_rate=0.05, n_estimators=120,max_depth=9, min_samples_split=1200,min_samples_leaf=60, subsample=0.85, random_state=10, max_features=7)
modelfit(gbm_tuned_1, train, predictors)
# Out:
# Model Report
# Accuracy : 0.9854
# AUC Score (Train): 0.897619
# cv_score: {'fit_time': array([7.97106528, 7.87524176, 7.8847115 , 8.00241518, 8.12547612]), 'score_time': array([0.08938003, 0.08102226, 0.09131527, 0.08123827, 0.09152102]), 'test_score': array([0.82712376, 0.83335986, 0.85112206, 0.84935487, 0.83470536]), 'train_score': array([0.90431469, 0.90376377, 0.90284495, 0.90409177, 0.90723199])}

# %%
predictors = [x for x in train.columns if x not in [target, IDcol]]
gbm_tuned_2 = GradientBoostingClassifier(learning_rate=0.01, n_estimators=600,max_depth=9, min_samples_split=1200,min_samples_leaf=60, subsample=0.85, random_state=10, max_features=7)
modelfit(gbm_tuned_2, train, predictors)
# Out:
# Model Report
# Accuracy : 0.9854
# AUC Score (Train): 0.899962
# cv_score: {'fit_time': array([38.26656365, 38.92848873, 38.37749219, 43.51912975, 39.54097557]), 'score_time': array([0.39885354, 0.40814662, 0.40081263, 0.35476565, 0.41806364]), 'test_score': array([0.82553787, 0.8359657 , 0.85263281, 0.8517257 , 0.8385021 ]), 'train_score': array([0.90541333, 0.90568624, 0.90300907, 0.90427946, 0.90723382])}

# %%
predictors = [x for x in train.columns if x not in [target, IDcol]]
gbm_tuned_3 = GradientBoostingClassifier(learning_rate=0.005, n_estimators=1200,max_depth=9, min_samples_split=1200, min_samples_leaf=60, subsample=0.85, random_state=10, max_features=7,
warm_start=True)
modelfit(gbm_tuned_3, train, predictors, performCV=False)
# Out:
# Model Report
# Accuracy : 0.9854
# AUC Score (Train): 0.900738

# %%
predictors = [x for x in train.columns if x not in [target, IDcol]]
gbm_tuned_3 = GradientBoostingClassifier(learning_rate=0.005, n_estimators=1200,max_depth=9, min_samples_split=1200, min_samples_leaf=60, subsample=0.85, random_state=10, max_features=7,
warm_start=True)
modelfit(gbm_tuned_3, train, predictors, performCV=False)
# Out:
# Model Report
# Accuracy : 0.9854
# AUC Score (Train): 0.900738
